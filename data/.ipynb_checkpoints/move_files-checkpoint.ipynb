# %%
import glob
import os
import shutil

# %%
files = glob.glob("./game_shots/*_home.csv")
files
# Out:
# ['./game_shots/0021500230_home.csv',
#  './game_shots/0021500056_home.csv',
#  './game_shots/0021500057_home.csv',
#  './game_shots/0021500231_home.csv',
#  './game_shots/0021500279_home.csv',
#  './game_shots/0021500278_home.csv',
#  './game_shots/0021500185_home.csv',
#  './game_shots/0021500184_home.csv',
#  './game_shots/0021500117_home.csv',
#  './game_shots/0021500116_home.csv',
#  './game_shots/0021500068_home.csv',
#  './game_shots/0021500069_home.csv',
#  './game_shots/0021500307_home.csv',
#  './game_shots/0021500021_home.csv',
#  './game_shots/0021500247_home.csv',
#  './game_shots/0021500246_home.csv',
#  './game_shots/0021500020_home.csv',
#  './game_shots/0021500129_home.csv',
#  './game_shots/0021500128_home.csv',
#  './game_shots/0021500087_home.csv',
#  './game_shots/0021500086_home.csv',
#  './game_shots/0021500015_home.csv',
#  './game_shots/0021500273_home.csv',
#  './game_shots/0021500272_home.csv',
#  './game_shots/0021500154_home.csv',
# ...

# %%
file_names = []
for file in files:
    file_names.append("./csv/"+file.split("./game_shots/")[1].split("_")[0]+"_converted.csv")
file_names
# Out:
# ['./converted/0021500230_converted.csv',
#  './converted/0021500056_converted.csv',
#  './converted/0021500057_converted.csv',
#  './converted/0021500231_converted.csv',
#  './converted/0021500279_converted.csv',
#  './converted/0021500278_converted.csv',
#  './converted/0021500185_converted.csv',
#  './converted/0021500184_converted.csv',
#  './converted/0021500117_converted.csv',
#  './converted/0021500116_converted.csv',
#  './converted/0021500068_converted.csv',
#  './converted/0021500069_converted.csv',
#  './converted/0021500307_converted.csv',
#  './converted/0021500021_converted.csv',
#  './converted/0021500247_converted.csv',
#  './converted/0021500246_converted.csv',
#  './converted/0021500020_converted.csv',
#  './converted/0021500129_converted.csv',
#  './converted/0021500128_converted.csv',
#  './converted/0021500087_converted.csv',
#  './converted/0021500086_converted.csv',
#  './converted/0021500015_converted.csv',
#  './converted/0021500273_converted.csv',
# ...

# %%
jsons = glob.glob("*.json")
jsons
# Out:
# ['0021500162.json',
#  '0021500174.json',
#  '0021500226.json',
#  '0021500158.json',
#  '0021500139.json',
#  '0021500210.json',
#  '0021500206.json',
#  '0021500178.json',
#  '0021500179.json',
#  '0021500207.json',
#  '0021500211.json',
#  '0021500138.json',
#  '0021500231.json',
#  '0021500159.json',
#  '0021500227.json',
#  '0021500175.json',
#  '0021500163.json',
#  '0021500187.json',
#  '0021500216.json',
#  '0021500200.json',
#  '0021500144.json',
#  '0021500164.json',
#  '0021500172.json',
#  '0021500148.json',
#  '0021500149.json',
#  '0021500173.json',
#  '0021500165.json',
#  '0021500145.json',
#  '0021500153.json',
#  '0021500190.json',
#  '0021500201.json',
#  '0021500217.json',
#  '0021500186.json',
#  '0021500150.json',
#  '0021500193.json',
#  '0021500202.json',
#  '0021500214.json',
#  '0021500170.json',
#  '0021500166.json',
#  '0021500189.json',
#  '0021500167.json',
#  '0021500188.json',
#  '0021500219.json',
#  '0021500171.json',
#  '0021500184.json',
# ...

# %%
for file in file_names:
#     try:
#         os.remove(file)
#     except:
#         print("Did not remove ",file)
    if os.path.exists(file):
        print(file)
        os.remove(file)
# Out:
# ./converted/0021500279_converted.csv
# ./converted/0021500278_converted.csv
# ./converted/0021500307_converted.csv
# ./converted/0021500273_converted.csv
# ./converted/0021500272_converted.csv
# ./converted/0021500296_converted.csv
# ./converted/0021500297_converted.csv
# ./converted/0021500311_converted.csv
# ./converted/0021500264_converted.csv
# ./converted/0021500265_converted.csv
# ./converted/0021500281_converted.csv
# ./converted/0021500280_converted.csv
# ./converted/0021500269_converted.csv
# ./converted/0021500268_converted.csv
# ./converted/0021500263_converted.csv
# ./converted/0021500262_converted.csv
# ./converted/0021500286_converted.csv
# ./converted/0021500287_converted.csv
# ./converted/0021500301_converted.csv
# ./converted/0021500300_converted.csv
# ./converted/0021500274_converted.csv
# ./converted/0021500275_converted.csv
# ./converted/0021500291_converted.csv
# ./converted/0021500290_converted.csv
# ./converted/0021500267_converted.csv
# ...

# %%
os.getcwd()
# Out:
# '/Users/elliottsloate/Documents/grad_school_classes/nba-movement-data/data'
